# %%
import pandas as pd

# %%
# Load the data

# %%
train = pd.read_csv("./data/train.csv")
train['timestamp'] = pd.to_datetime(train['timestamp'])
train
# Out:
#                              timestamp  Asset_ID  Count          Open  \
# 0        1970-01-01 00:00:01.514764860         2   40.0   2376.580000
# 1        1970-01-01 00:00:01.514764860         0    5.0      8.530000
# 2        1970-01-01 00:00:01.514764860         1  229.0  13835.194000
# 3        1970-01-01 00:00:01.514764860         5   32.0      7.659600
# 4        1970-01-01 00:00:01.514764860         7    5.0     25.920000
# ...                                ...       ...    ...           ...
# 24236801 1970-01-01 00:00:01.632182400         9  775.0    157.181571
# 24236802 1970-01-01 00:00:01.632182400        10   34.0   2437.065067
# 24236803 1970-01-01 00:00:01.632182400        13  380.0      0.091390
# 24236804 1970-01-01 00:00:01.632182400        12  177.0      0.282168
# 24236805 1970-01-01 00:00:01.632182400        11   48.0    232.695000
#
#                   High           Low         Close        Volume  \
# ...

# %%
# Out:
# 0          1970-01-01 00:00:01.514764860
# 1          1970-01-01 00:00:01.514764860
# 2          1970-01-01 00:00:01.514764860
# 3          1970-01-01 00:00:01.514764860
# 4          1970-01-01 00:00:01.514764860
#                         ...
# 24236801   1970-01-01 00:00:01.632182400
# 24236802   1970-01-01 00:00:01.632182400
# 24236803   1970-01-01 00:00:01.632182400
# 24236804   1970-01-01 00:00:01.632182400
# 24236805   1970-01-01 00:00:01.632182400
# Name: timestamp, Length: 24236806, dtype: datetime64[ns]
